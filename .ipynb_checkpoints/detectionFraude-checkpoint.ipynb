# %%
from faker import Faker

import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

from tqdm import tqdm
import random
import uuid

# %%
fake = Faker()

customer_list = []

for i in tqdm(range (500)):
    customer_id = str(uuid.uuid4())
    first_name = fake.first_name()
    last_name = fake.last_name()
    domain = fake.domain_name()
    email = f"{last_name.lower()}.{first_name.lower()}@{domain}"
    phone_number = "+237 6" + "".join(random.choices('2578', k=1)) + "".join(random.choices("0123456789", k=8))
    registration_date = fake.date_time_between(start_date = '-4y', end_date = 'now')
    date_of_birth = fake.date_of_birth(minimum_age=17, maximum_age=90)
    address = fake.address()
    city = fake.city()
    region = fake.state()

    customer_dict = {
        "customer_id": customer_id,
        "first_name": first_name,
        "last_name": last_name,
        "email": email,
        "phone_number": phone_number,
        "registration_date": registration_date,
        "date_of_birth": date_of_birth,
        "address": address,
        "city": city,
        "region": region
    }

    customer_list.append(customer_dict)

customer_df = pd.DataFrame(customer_list)

customer_df.head()

customer_df.to_csv('customer.csv', index=False)

# Créer une liste de customer_id
# customer_id_list = list(customer_df.customer_id)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 1525.61it/s]

# %%
# customer_id_list = []

# for customer in customer_list:
#     customer_id_list.append(customer_id)
    
# #customer_id_list

# customer_id_list = [customer['customer_id'] for customer in customer_list]
# customer_id_list

customer_id_list = list(customer_df.customer_id)
customer_id_list

# customer_df.tail()
# Out:
# ['e9440399-8e0f-41bc-b552-848b6e17cc65',
#  '6f579863-0cd6-4ac6-9cba-9ee57fdab4f1',
#  'd408629c-1d4b-456f-b5c5-5304e3fd24eb',
#  'ce45c2f3-156c-42fa-a303-e8116f71b846',
#  'b909858a-4849-4a59-a5b7-3d8501d4c933',
#  'f823164b-2a44-4e8b-88bc-a19e62149a1b',
#  '740bad20-7fde-43de-aea7-5f51391e73c0',
#  '37b7ae73-cccf-445e-9181-cb1669f9ed01',
#  'db3f7ce5-d720-4b7d-a44c-71dca5d6cfaf',
#  '66ab15a2-5d57-4165-b257-27ee80b6a6fa',
#  'c6e4a32e-ff62-4551-aa12-f952001c318f',
#  'a867ab61-6be6-4420-b767-613b5256fb79',
#  'a8690b6d-ec07-45e5-ac72-4d3dbc0ef053',
#  '15168064-121a-43c7-8108-be406a038051',
#  '7483570f-bf2a-4bc2-899c-2a0de73349b5',
#  '56ffc48b-1859-40ad-80fc-3550ee957d69',
#  '814db3a3-53e3-439b-9b4d-8cdf1a930317',
#  '571dded2-d389-484c-9eb0-a0e9205b746d',
#  'dcdc8d88-da5c-4bcc-82b7-81aeb4cf8165',
#  '29a006bb-f2d3-4ca1-8657-fe1cd8ca63e8',
#  '44100aeb-d3b9-4c90-abf2-e4280fa07975',
#  'da112b24-ad1f-4d13-9c22-1a93942200d3',
#  'da2ae6ee-c6ca-45b4-bd33-e4de42a0ea0b',
#  '05e4d950-3006-4d9f-a33a-82ccb92d9417',
#  'f1c1d2ce-77d2-4d1b-a639-bb865f23b1a9',
#  '86fb6bdd-440e-4306-b69e-fe63ab47c369',
#  'a49f3c09-841e-418c-96f9-7d3985ac8849',
#  '50469736-a24f-4e59-9b4b-ddb2bceed9b7',
#  '5aa5b730-be86-49dd-8ae8-250e38ab3a56',
#  'c33e80d5-63e8-439d-8642-0204b1eab313',
#  '7a871732-951a-4687-bcd4-f218c67f2f8a',
#  '36e4c966-c949-409e-8d0b-b8e758dd8ac4',
#  'aa91dba3-cbfb-4c83-86e9-bf4c797a93b0',
#  'b77bc2bf-a47e-4e14-b377-684808530eb5',
#  '6ceaf3ae-9c4d-49f0-969d-d63b0ec7e0fd',
#  '22edf144-80ae-429e-8bc1-eb2d94ab8c2c',
#  '5865e885-995a-4e6b-83bf-003aa3d3e29e',
#  'fff4ce76-6c83-4c80-8828-6695a25448e5',
#  '598f5c37-929d-4fed-a172-d732ec61efe8',
#  '58cbff69-1afb-4ef9-a4c9-9705511c1c70',
#  'c1c6af7b-74d2-4bea-9f58-c216e22bf198',
#  '02e16256-80ab-4497-a3ab-86f86802717f',
#  '7b8a777a-9f6b-4174-8a19-54257b3e9298',
#  'b825173f-2765-4952-83e1-0056f0c8382e',
#  'e641cf6a-7fc0-4a1c-aba4-6f7921faa676',
#  'f0296ee9-6765-4cad-bd30-2656373d4b59',
#  '2993625f-c743-4ab4-a70d-c43bb20c682e',
#  '4430a301-d7e9-48b8-9441-f399f3b11f48',
#  '5aa8ec55-ace1-4651-931b-9f03edc8c9cd',
#  '8f2de09f-dd59-498d-866b-e4978dc9908e',
#  'df383666-8041-432b-96ea-bcb1673246a2',
#  'ef30cc4d-d947-4991-b459-c0e776e6a59a',
#  '06996d83-b527-40e4-9651-6258f639a060',
#  '33a550a1-31f0-4883-a2e8-e44161fa196d',
#  'b585c978-c5d4-48c7-890e-051a87fa1bff',
#  '882e3d42-9038-4d66-9634-97db861bc343',
#  '8558bc3b-ed2f-45ec-aeeb-5fafbbcb7169',
#  'db3c13a8-daed-4921-9bfd-adf5709c37e0',
#  '9e3d4e09-d8d0-40f5-83f5-ff499f31e6ea',
#  'd211451d-8d22-45ff-9ef8-81434bdf1dc2',
#  '2b999ca0-9488-4b66-9460-7f58a26326f6',
#  '8bb3b18b-eb99-40f4-a452-2989d2a20500',
#  'ae4d1447-720f-47ce-9bac-e8f46316d7c1',
#  '9a57ec07-518f-458a-bdc7-8b5fdc4954cd',
#  'f3f92b86-9b3d-4cf2-ab59-b0afe3856622',
#  '1b2ba761-453b-4398-ae3d-2ab651fea8c5',
#  'cb62cf39-0480-4ccb-9c0d-1f6f39e8b3cd',
#  '5c458e93-5e22-4cf2-a0d3-4b3dfd251883',
#  'a9e68693-e282-4813-bd84-6472e4e13d39',
#  'd10b8eaf-883c-4f63-b7cf-45b6f151cdc3',
#  'dc3c4cc7-8024-468e-8bd7-88875973ca3e',
#  '49eb0ca0-5747-4b9a-840b-9b709dcd9904',
#  'f4ee3de8-751b-4d40-86e2-a2b4c1778910',
#  'edb5fb16-c11f-4915-875a-505715886378',
#  'f1aa4cdf-d567-4f85-bc44-b0ac750787e5',
#  '28c0757e-1fb2-4d39-95c4-106efe168ec4',
#  'c0dc1a01-668e-4dcb-811c-7327cb71ec40',
#  '8fb82562-debc-492e-b008-f573afa9af65',
#  '1f351b19-d516-400f-83e6-456255cd85c1',
#  '430465b4-a2ac-41a4-9195-340cbc8e2576',
#  'e3c6ee99-595e-4b78-bf84-df356a7ad514',
#  'd19eb966-e1cf-4c75-98d4-1cd6da7bbb6c',
#  '5d7c7824-ca58-4d14-9865-919ec28609f1',
#  'f4fcf2f6-4fd3-4b6e-857f-5120bd698902',
#  '5c8a8e26-8983-4992-a695-c5954d127a99',
#  '3d4a1985-417b-42b5-9ddc-787d4742de7a',
#  'a5558b91-6491-49d4-b60c-7ccb3073542f',
#  'f0e9b808-3c7b-48c8-beb0-edebc4ecd1d8',
#  '19b1ee7b-8fff-4ce5-b81f-9f64311c940e',
#  'b79112eb-9261-48e0-87ce-c8506089c0a2',
#  '255b245c-b2af-4b90-bbe0-4b38da86d6f6',
#  '1db87648-15ce-48ad-b24a-319714563e80',
#  'e688ebab-5377-4186-8e2c-b90ebe269a4e',
#  'a97f77b7-880d-418c-ad01-a50a49f6e1de',
#  'd6624cea-84dd-4822-b772-b2d300cb2546',
#  '0bef0c1f-edfc-4439-83f1-f6a6125cf729',
#  '156e21c3-66c2-42c0-86db-6933853f408e',
#  '4bdd51b1-d91f-4491-b9a5-ff1d5a5c8207',
#  'df528d13-4312-4c71-a834-4eceedfb3d1b',
#  'f827c308-72e1-4c2a-9926-23ea6e89be6e',
#  '64f8dee0-28d8-44ec-8215-faa21b8ee0f9',
#  'e9d30d21-c453-43b4-8334-cd36d9986d13',
#  'c4dd44f1-12e9-4546-b54c-dc63a1751a22',
#  'c3dc4798-9882-4b79-aec1-34cc890ce61b',
#  'ffa7796c-17ba-4742-bc7a-f5601b959221',
#  'cefda5f6-1255-4ee4-9c1d-ccf2923574f5',
#  '193f26de-7e5e-4c5b-9497-88d74daf9185',
#  'd0a072bc-22db-4f66-8a82-b113addc88ca',
#  'dd311944-846f-4d95-9eff-6f0254d2ad26',
#  'fc36f6f6-7e03-45ea-aa2e-24bd98c88809',
#  '6c1cd25e-7641-4836-b7a5-2a5861e32651',
#  'db4a845a-34fa-4544-9ffd-78fde9d375d7',
#  '72a79dce-8184-4219-9f63-e1fa8e17ff8b',
#  '400b5031-6434-451d-9e9d-c6628c7c8027',
#  '40c8fc38-38e3-49a4-8e3d-8f2daa3afa15',
#  '5792605f-34e2-4b55-9a5b-8105201cc722',
#  '316f48af-f081-46da-931c-88ce0bd9aca5',
#  '33e65e6c-cbf1-471e-a245-1e3ffaf3120d',
#  '0f2046d5-5ff0-40f6-8498-9d879c9aec88',
#  '19167429-1168-476e-9799-9cbc22c518b9',
#  'fc3c2fd7-728a-4380-ae4a-6ef4181abc42',
#  'd97c6f6a-d8ab-4d92-a8eb-98df71fac94d',
#  'a3d232a3-db06-4bdd-b7fa-f28ebef1cc31',
#  '8d5e75a6-0660-4d7f-acce-a34760669221',
#  '11e2c056-da0c-44e5-81e4-1b11526978a6',
#  'db49501d-db93-4045-a0f5-7a4e54cb002f',
#  'cf16e8f5-ef78-48f4-aeb1-e03969d6617f',
#  'a6893a3b-26f7-444d-bebf-f9ec6bfb3186',
#  '7178b3cc-27d9-4160-b66d-b2a9591ef550',
#  'f24a8d0f-8250-4806-b322-4a414c197e6e',
#  '22cd2bd6-5c70-405a-9975-b0a093949939',
#  '34bbe426-e37e-4df3-8fdc-f244fb19ad8e',
#  '226d1989-7ab5-4746-8e6f-94b4c7329743',
#  'e5a41894-6ab9-44e6-b665-25b90ab93c58',
#  '7bf256a9-ac9a-4991-9b37-a955f7b056a1',
#  '6c11422d-3504-447c-bbc9-3abfe7158333',
#  '0c23f31a-d805-440c-8f4d-a30019706f66',
#  '317f4f04-95f9-4449-948d-1cbbc19a140d',
#  'cd862047-232d-49f5-bd9e-0b200a8ac052',
#  '89fd2d14-7548-4ec5-9eca-a3d0945a655a',
#  '7026318f-ece4-4e01-a1b2-ce43a56bce87',
#  '777bb35d-6307-4fb1-8ec7-05947b7a605e',
#  'ffe58ac7-2198-4ab6-94a3-5d24e58fa172',
#  '9435c8da-70c9-4af6-8935-424a03d745f3',
#  'c368eb79-e4d7-475b-ad06-74c134480fae',
#  '1353ef00-48a0-40d4-83be-d941e81b5076',
#  '329f6b2c-68cb-490b-9d6a-e95a580a5bb5',
#  'c74500f4-e48d-46d2-824c-0a40fd2991d2',
#  '032507ea-b1c3-4c15-9348-0d54c1ee257a',
#  '5f95ed22-9fdd-4007-9a64-5936b21607fc',
#  '5dcc255e-767f-492a-9cc9-5da19f8610d1',
#  '6a380030-9e18-4f0c-9687-3fe326f8fd28',
#  '06c5daac-cd98-46fe-9782-11bfdab83650',
#  'fb43c4d5-a290-454c-9b68-2454029cba85',
#  '10147bd1-d66b-4cff-8b27-21de3fcba887',
#  '7f1c5d5a-4a44-4521-9ef1-b7ec3a29c08d',
#  'a9ed27b6-0e7f-413a-afe3-10255973bbf4',
#  'e55fdde1-5d34-4bb4-ad4b-5de0aa878141',
#  'a939133f-7cd3-400c-89a7-c31dff230351',
#  '34cc75a8-3e07-466f-80ca-cae17b9863af',
#  '61bd2540-c795-48c7-935c-ce101ccde5e6',
#  'bb96d71c-3d63-416e-8a1a-8790759c4581',
#  '90a86555-92ae-49f2-b7a9-802e3025965f',
#  'ffb4e6c9-75e3-4b12-b7cc-23f8a31ebec6',
#  'e5e69fe7-21aa-4003-b615-807c72676a8a',
#  'aac8be2e-e7ce-4dc5-8fc9-f815f9dc7f97',
#  '1f0aaf79-0d59-4e2a-ab9a-c18f305d90e4',
#  '30f53ff9-ff26-49dd-b93e-e062e66b2344',
#  'a647a9c3-c303-4019-b436-106e4c3b3346',
#  '474bf22e-fa37-4b65-9daa-be135b1c6d36',
#  '9594e1df-3db5-41f0-a01e-f0e7c762e774',
#  '66ae8888-116e-4e72-827a-1a1a03c526ad',
#  '305c55a6-f97a-4f71-b436-7bd685603f62',
#  'bfd9d6de-502e-48e7-87f1-4f0bfebf82c0',
#  'c3644d8d-3151-4c9b-b6b7-ffc938aa10d9',
#  'f16959b4-48fd-4d58-98de-d2dfe0e80bca',
#  '898de33f-e381-4863-8984-6a5a019c4d47',
#  '835278de-f011-48a0-abb4-ee98715ab14e',
#  '008b4ce6-e7cd-4603-8eac-2c40e7396e7f',
#  '86af6ab0-e4b1-439b-a221-751e57f8f497',
#  '615644dc-9481-4bde-9e6d-1ef1c3008f66',
#  'a80c3c26-6fff-402e-97b7-07b37d709da8',
#  '7cbd859d-6c5e-49a0-b3c4-b2d364032985',
#  'f405ddc8-572e-46ee-9936-807c26fa0f6b',
#  '999d20eb-9596-44b2-8553-d32b933bb315',
#  '76c16bde-4388-4d11-be52-73ddac66b7c0',
#  '1754eca9-9e82-4660-a773-5978f7f9e415',
#  '5fc3ab89-149a-418d-8418-f48310a135cd',
#  'f7c8eb4c-d434-4c03-8e38-752d81b5896f',
#  '4c4c0e7f-e994-4b65-bb47-525e134daf21',
#  'd3ec1388-1495-405e-bcd9-9792021743ac',
#  'fc613ab1-239a-46ec-956e-1bd3cac342c2',
#  'fcfb7d41-4dc1-40a0-adef-b241b42883de',
#  'd33ada8f-1d26-4ab3-8222-d6bc858dcba9',
#  '009d88d7-fc91-4232-9128-c70d526c3b29',
#  'c142a35d-8b79-4d17-a99d-94aebcd63041',
#  '87607d1e-2e0b-4464-9393-2fdb14502afd']

# %%
device_list = []

for i in tqdm(range (500)):
    device_id = str(uuid.uuid4())
    device_type = fake.random_element(elements=('smartphone', 'tablet', 'cellulaire'))
    os = fake.random_element(elements=('iOS', 'Android', 'os blackberry'))
    manufacturer = fake.company()
    model = fake.word()
    last_used = fake.date_time_between(start_date='-1y', end_date='now')

    device_dict = {
        "device_id" : device_id,
        "device_type" : device_type,
        "os" : os,
        "manufacturer" : manufacturer,
        "model" : model,
        "last_used" : last_used 
    }
    
    device_list.append(device_dict)

device_df = pd.DataFrame(device_list)

device_df.head()

device_df.to_csv('device.csv', index=False)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 3395.84it/s]

# %%
transaction_list = []

for i in tqdm(range (500)):
    transaction_id = str(uuid.uuid4()) 
    customer_id = random.choice(customer_id_list)  # Choisir un customer_id aléatoire
    transaction_type = random.choice(['sending', 'receiving', 'purchase', 'refund','transfer'])
    amount = round(random.uniform(1000, 1000000), 2)  # Generate random amount between 10 and 1000
    transaction_date = fake.date_time_between(start_date='-4y', end_date='now')
    location = fake.city()
    status = random.choice(['success', 'failed', 'pending'])
    is_fraud = random.choice([True, False])  # Generate random fraud flag

    transaction_dict = {
        "transaction_id": transaction_id,
        "customer_id": customer_id,
        "transaction_type": transaction_type,
        "amount": amount,
        "transaction_date": transaction_date,
        "location": location,
        "device_id": device_id,
        "status": status,
        "is_fraud": is_fraud
    }

    transaction_list.append(transaction_dict)

transaction_df = pd.DataFrame(transaction_list)

transaction_df.head()

transaction_df.to_csv('transaction.csv', index=False)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 6813.65it/s]

# %%
transaction_df.customer_id.nunique()
# Out:
# 309

# %%
transHistory_list = []

for i in tqdm(range (500)):
    history_id = str(uuid.uuid4())
    previous_balance = round(random.uniform(100, 1000), 2)
    new_balance = previous_balance + round(random.uniform(-500, 500), 2)
    transaction_date = fake.date_time_between(start_date='-1y', end_date='now')

    transHistory_dict = {
        "'history_id" : history_id,
        "customer_id" : customer_id,
        "transaction_id" : transaction_id,
        "previous_balance": previous_balance,
        "new_balance" : new_balance,
        "transaction_date" : transaction_date
    }
    
    transHistory_list.append(transHistory_dict)

transaction_history_df = pd.DataFrame(transHistory_list)

transaction_history_df.head()

transaction_history_df.to_csv('transaction_history.csv', index=False)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 28381.70it/s]
